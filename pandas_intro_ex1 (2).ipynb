# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
import pandas as pd
df = pd.read_csv('/content/emendas.csv')
df.head(10)
# Out:
# /tmp/ipykernel_8215/420280567.py:2: DtypeWarning: Columns (0,3,5,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/emendas.csv')
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Sem comentários nessa primeira questão, vimos apenas o comando para importar e ver as primeiras 10 linhas do arquivo.

# %% [markdown]
# Explique em uma frase o que você observa nas primeiras 10 linhas.

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
df.shape
# Out:
# (36371, 28)

# %% [markdown]
# O arquivo possui 36371 linhas e 28 colunas.

# %% [markdown]
# Explique o que esses números significam.

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
df.columns
# Out:
# Index(['Código da Emenda', 'Ano da Emenda', 'Tipo de Emenda',
#        'Código do Autor da Emenda', 'Nome do Autor da Emenda',
#        'Número da emenda', 'Localidade de aplicação do recurso',
#        'Código Município IBGE', 'Município', 'Código UF IBGE', 'UF', 'Região',
#        'Código Função', 'Nome Função', 'Código Subfunção', 'Nome Subfunção',
#        'Código Programa', 'Nome Programa', 'Código Ação', 'Nome Ação',
#        'Código Plano Orçamentário', 'Nome Plano Orçamentário',
#        'Valor Empenhado', 'Valor Liquidado', 'Valor Pago',
#        'Valor Restos A Pagar Inscritos', 'Valor Restos A Pagar Cancelados',
#        'Valor Restos A Pagar Pagos'],
#       dtype='object')

# %% [markdown]
# Ao todo, o arquivo possui 28 colunas que simbolizam aspectos da emenda (código, ano, tipo, autor, número da emenda) , aspectos do local de aplicação do recurso (município , UF, região) , aspectos da função (nome, código da subfunção, nome da subfunção) , aspectos do programa (código do programa, nome do programa) , aspectos de plano orçamentário (nome, valor empenhado, valor liquidado, valor pago, restos a pagar dos inscritos e dos cancelados, resto a pagar que foram pagos)

# %% [markdown]
# Escreva sua breve descrição das colunas, como se estivesse criando um dicionário de variáveis para que leitor entenda.

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
nulos = df.isnull().sum()
print(nulos)
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             1
# Código UF IBGE                        1
# UF                                    1
# Região                                1
# Código Função                         1
# Nome Função                           1
# Código Subfunção                      1
# Nome Subfunção                        1
# Código Programa                       1
# Nome Programa                         1
# Código Ação                           1
# Nome Ação                             1
# Código Plano Orçamentário             1
# Nome Plano Orçamentário               1
# Valor Empenhado                       1
# ...

# %% [markdown]
# É visível a presença de valores nulos em alguns campos do arquivo, em colunas específicas mas sem oscilações extremas. Ou não tem valor nulo na coluna ou tem, no máximo, uma coluna.

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36371 entries, 0 to 36370
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Código da Emenda                    36371 non-null  object
#  1   Ano da Emenda                       36371 non-null  int64
#  2   Tipo de Emenda                      36371 non-null  object
#  3   Código do Autor da Emenda           36371 non-null  object
#  4   Nome do Autor da Emenda             36371 non-null  object
#  5   Número da emenda                    36371 non-null  object
#  6   Localidade de aplicação do recurso  36371 non-null  object
#  7   Código Município IBGE               36371 non-null  object
#  8   Município                           36370 non-null  object
#  9   Código UF IBGE                      36370 non-null  float64
#  10  UF                                  36370 non-null  object
# ...

# %% [markdown]
# A maioria das variáveis está corretamente tipada, com campos em object e 'Ano da Emenda' como int64, porém existem inconsistências importantes:'Código UF IBGE' aparece como float64 quando deveria ser int, muito provável que seja por existirem valores nulos, e todas as variáveis de valor financeiro estão em object mas deveria ser float, oque mostra problemas na formatação dos daods, como uso de vírgulas ou símbolos monetários.

# %% [markdown]
# Se alguma coluna estiver com o tipo errado, escreva abaixo qual é e por que isso pode atrapalhar análises.
#
# **Dica:** Se alguma variável tiver no tipo o nome "object", isso se refere a texto.

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
df_sorted = df.sort_values(by='Ano da Emenda', ascending=False)
df_sorted.head(8)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 36340     201815040008           2018
# 36354     201836980005           2018
# 36370     201836980022           2018
# 36369     201836980021           2018
# 36353     201836980004           2018
# 36352     201836980003           2018
# 36351     201836980002           2018
# 36350     201836980001           2018
#
#                                           Tipo de Emenda  \
# 36340  Emenda Individual - Transferências com Finalid...
# 36354  Emenda Individual - Transferências com Finalid...
# 36370  Emenda Individual - Transferências com Finalid...
# 36369  Emenda Individual - Transferências com Finalid...
# 36353  Emenda Individual - Transferências com Finalid...
# 36352  Emenda Individual - Transferências com Finalid...
# 36351  Emenda Individual - Transferências com Finalid...
# 36350  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# ...

# %% [markdown]
# Como o comando dado foi de intuito aleatório, o último ano que aparece no meu google colab é o ano de 2018, embora na máquina de outros usuários o último ano de atualização seja 2025.

# %% [markdown]
# Explique: qual é o ano mais recente presente no dataset?

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
df.describe()
# Out:
#        Ano da Emenda  Código UF IBGE
# count   36371.000000    3.637000e+04
# mean     2015.759424    3.079555e+06
# std         1.398544    1.129218e+06
# min      2014.000000   -1.400000e+01
# 25%      2014.000000    2.400000e+06
# 50%      2016.000000    3.100000e+06
# 75%      2017.000000    4.100000e+06
# max      2018.000000    5.300000e+06

# %% [markdown]
# Acredito que o motivo pelo qual outras colunas não aparecem no describe() é que, por padrão, apenas aparecem colunas numéricas, deixando de lado as colunas do tipo objeto. Em suma, é visível as estastícas apenas das colunas numéricas 'Ano da Emenda' e 'Código UF IBGE'. Para 'Ano da Emenda', os ados vão de 2014 a 2018, indicando um dataset concentrado nesses anos.

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
df.tail()
# Out:
#       Código da Emenda  Ano da Emenda  \
# 36366     201836980018           2018
# 36367     201836980019           2018
# 36368     201836980020           2018
# 36369     201836980021           2018
# 36370     201836980022           2018
#
#                                           Tipo de Emenda  \
# 36366  Emenda Individual - Transferências com Finalid...
# 36367  Emenda Individual - Transferências com Finalid...
# 36368  Emenda Individual - Transferências com Finalid...
# 36369  Emenda Individual - Transferências com Finalid...
# 36370  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 36366                      3698          JUNIOR MARRECA               18
# 36367                      3698          JUNIOR MARRECA               19
# 36368                      3698          JUNIOR MARRECA               20
# 36369                      3698          JUNIOR MARRECA               21
# ...

# %% [markdown]
# A última linha definitivamente não parece completa. Vários campos da última linha parecem estar incompletas, onde aparece apenas as letras "NaN".

# %% [markdown]
# Interprete a completude da última linha.

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
duplicated = df.duplicated().sum()
print(duplicated)
# Out:
# 0

# %% [markdown]
# No dataframe aprasentado, não aparece nenhum valor duplicado.
